# %%
import numpy as np

import pandas as pd
from pandas.plotting import scatter_matrix

from scipy import stats
import scipy as sc

import matplotlib.pyplot as plt
import seaborn as sns

from random import randrange

import re

import random
import pickle,pprint

from scipy.stats import gamma
from scipy.optimize import minimize

from matplotlib import rc

# %matplotlib inline

# %%
rc('text', usetex=True)

# this is just to have figure with large fontsize
params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (8, 5),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)


plt.rc('font', weight='bold')
plt.rc('xtick.major', size=5, pad=7)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
plt.rc('axes', labelsize=24)
plt.rc('axes', titlesize=24)

# %%
#param

d=2 #ms
v_max=0.6 #[kHZ]
mu_0=0
h_0=0
beta=1

# %%
def phi(h):
    return v_max/(1+np.exp(-beta*(h-h_0)))

# %% [markdown]
# ## Poisson Process with absolute refractory period

# %%
def RHO_poisson(tau,nu,d):
    if tau< d:
        return 0 
    else:
        return nu

def S_poisson(tau,nu,d):
    if tau <d:
        return 1
    else:
        return np.exp(-nu*(tau-d))
    
def P_poisson(tau,nu,d):
    if tau <d:
        return 0
    else:
        return nu*np.exp(-nu*(tau-d))
    
    

def RHO_2(tau,nu,d,l):
    if tau< d:
        return 0 
    else:
        return nu*(1-np.exp(-l*(tau-d)))

def S_2(tau,nu,d,l):
    if tau <d:
        return 1
    else:
        return np.exp(-nu*(tau-d))*np.exp(RHO_2(tau,nu,d,l)/l)
    
def P_2(tau,nu,d,l):
    return RHO_2(tau,nu,d,l)*S_2(tau,nu,d,l)

# %% [markdown]
# # Non constant input

# %%
nu=phi(mu_0)
print(nu)
d=5
l=0.2
dt=0.05
tau_max=30


N=int(tau_max/dt)

tau_vec=[(j)*dt for j in range(N+1)]
t_vec=[(j)*dt for j in range(N_sim)]
# Out:
# 0.3

# %%
P_=[P_poisson(t,nu,d) for t in tau_vec]
S_=[S_poisson(t,nu,d) for t in tau_vec]
RHO_=[RHO_poisson(t,nu,d) for t in tau_vec]

P_2p=[P_2(t,nu,d,l) for t in tau_vec]
S_2p=[S_2(t,nu,d,l) for t in tau_vec]
RHO_2p=[RHO_2(t,nu,d,l) for t in tau_vec]

# %%
plt.figure(figsize=(16, 4))

plt.subplot(131)
plt.plot(tau_vec,RHO_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$\rho(\tau,h_0)$ [kHz]')
plt.xlim(0,tau_max)
plt.ylim(0,0.31)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))

plt.subplot(132)
plt.plot(tau_vec,P_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$P(\tau,h_0)$')
plt.xlim(0,tau_max)
plt.ylim(0,0.31)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))


plt.subplot(133)
plt.plot(tau_vec,S_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$S(\tau,h_0)$')
plt.xlim(0,tau_max)
plt.ylim(0,1.1)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))

plt.subplots_adjust(top=0.92, bottom=0.22, left=0.10, right=0.95, hspace=0.35,
                    wspace=0.45)
plt.savefig('poissonRHOSP.pdf')

# %%
plt.figure(figsize=(16, 4))



plt.subplot(131)
plt.plot(tau_vec,RHO_2p,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$\rho(\tau,h_0)$ [kHz]')
plt.xlim(0,tau_max)
plt.ylim(0,0.31)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))

plt.subplot(132)
plt.plot(tau_vec,P_2p,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$P(\tau,h_0)$')
plt.xlim(0,tau_max)
plt.ylim(0,0.31)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))


plt.subplot(133)
plt.plot(tau_vec,S_2p,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$S(\tau,h_0)$')
plt.xlim(0,tau_max)
plt.ylim(0,1.1)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))

plt.subplots_adjust(top=0.92, bottom=0.22, left=0.10, right=0.95, hspace=0.35,
                    wspace=0.45)
plt.savefig('expRHOSP.pdf')

# %% [markdown]
# INVERSE GAUSSIAN

# %%
a=100#int(1/(2*D))
b=6#a*mut_window=250
dt=0.05
tau_max=30
N=int(tau_max/dt)

tau_vec=[(j)*dt for j in range(N+1)]

# %%
def S(t,a,b):
    return 1-sc.special.gammainc(a,b*t)

def P(t,a,b):
    return (b**a)*(t**(a-1))*np.exp(-b*t)/sc.special.gamma(a)

def RHO(t,a,b):
    return P(t,a,b)/S(t,a,b)

# %%
P_=[P(t,a,b) for t in tau_vec]
S_=[S(t,a,b) for t in tau_vec]
RHO_=[RHO(t,a,b) for t in tau_vec]

# %%
plt.figure(figsize=(16, 4))

plt.subplot(131)
plt.plot(tau_vec,RHO_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$\rho(\tau,h_0)$ [kHz]')
plt.xlim(0,tau_max)
plt.ylim(0,3)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))

plt.subplot(132)
plt.plot(tau_vec,P_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$P(\tau,h_0)$')
plt.xlim(0,tau_max)
plt.ylim(0,0.4)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))


plt.subplot(133)
plt.plot(tau_vec,S_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$S(\tau,h_0)$')
plt.xlim(0,tau_max)
plt.ylim(0,1.1)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))

plt.subplots_adjust(top=0.92, bottom=0.22, left=0.10, right=0.95, hspace=0.35,
                    wspace=0.45)
plt.savefig('gamma.pdf')

# %% [markdown]
# # INVERSE GAUSSIAN

# %%
D=0.125
V_th=1
mu=1


t_max=10
dt=0.01
N_sim=int(t_max/dt)
          
t_vec=[dt*i for i in range(N_sim+1)]          

mean = 0
std = 1 

samples = np.random.normal(mean, std, size=N_sim+1)
V_t=np.zeros((N_sim+1,1))
    
sup= False
for i in range (N_sim):
    if sup==False:
        V_t[i+1]=V_t[i]+dt*(mu+np.sqrt(2*D)*samples[i])
    else:
        V_t[i+1]=0
        sup=False
        
    if V_t[i+1]>=1:
        V_t[i+1]=1
        sup=True

# %%
plt.plot(t_vec,V_t)

# %%
from scipy.stats import norm

# Process parameters
delta = 2*D
dt = 0.1

V_th=1
mu=1

t_max=10
dt=0.01
N_sim=int(t_max/dt)
          
t_vec=[dt*i for i in range(N_sim+1)]   

V_t=np.zeros((N_sim+1,1))

# Iterate to compute the steps of the Brownian motion.
for i in range (N_sim):  
    if sup==False:
        V_t[i+1] = V_t[i] +dt*mu+ norm.rvs(scale=delta**2*dt)
    else:
        V_t[i+1]=0
        sup=False
        
    if V_t[i+1]>=1:
        V_t[i+1]=1
        sup=True

# %%
plt.plot(t_vec,V_t)

# %%
#Cv=0.3
#R=0.05

#V_th=1
#mu=R*V_th
#D=0.5*mu*V_th*Cv**2

D=0.1
V_th=1
mu=0.3


t_window=30
dt=0.1
N=int(t_window/dt)

N_sim=int(150/dt)

t_vec=[dt*(i+1) for i in range(N)]

def Prcv(t,mu,V_th,D):
    
    R=mu/V_th
    Cv=np.sqrt(2*D/(mu*V_th))
    
    if t==0:
        return 0
    else:
        return (Cv**(-1)/(np.sqrt(2*np.pi*R*t**3)))*np.exp(-Cv**(-2)*(R*t-1)**2/(2*R*t))
    
def P(t,mu,V_th,D):
    
    
    if t==0:
        return 0
    else:
        return (V_th/(np.sqrt(4*np.pi*D*t**3)))*np.exp(-(mu*t-V_th)**2/(4*D*t))

 
def PHI(x):
    return 0.5*(1+sc.special.erf(x/np.sqrt(2)))

# %%
def S(t,mu,V_th,D):
      
    if t==0:
        return 1
    else:
        return 1-PHI(np.sqrt(V_th**(2)/(t*2*D))*(t*mu/V_th-1))-np.exp(mu*V_th/D)*PHI(-np.sqrt(V_th**(2)/(t*2*D))*(t*mu/V_th+1))

# %%
def RHO(t,mu,V_th,D):
    if t==0:
        return 0
    else:  
        return P(t,mu,V_th,D)/S(t,mu,V_th,D)#-(np.log(S(t+dt))-np.log(S(t-dt)))/(2*dt)

# %%
tau_max=30
N=int(tau_max/dt)

tau_vec=[(j)*dt for j in range(N+1)]

# %%
P_=[P(t,mu,V_th,D) for t in tau_vec]
S_=[S(t,mu,V_th,D) for t in tau_vec]
RHO_=[RHO(t,mu,V_th,D) for t in tau_vec]

# %%
plt.figure(figsize=(16, 4))

plt.subplot(131)
plt.plot(tau_vec,RHO_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$\rho(\tau,h_0)$ [kHz]')
plt.xlim(0,tau_max)
plt.ylim(0,0.5)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))

plt.subplot(132)
plt.plot(tau_vec,P_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$P(\tau,h_0)$')
plt.xlim(0,tau_max)
plt.ylim(0,0.32)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))


plt.subplot(133)
plt.plot(tau_vec,S_,lw=2)
plt.xlabel(r'$\tau$ [ms]')
plt.ylabel(r'$S(\tau,h_0)$')
plt.xlim(0,tau_max)
plt.ylim(0,1.1)
#plt.title(r'$ \nu= {}\:,\:\: \Delta={}$'.format(nu,d))

plt.subplots_adjust(top=0.92, bottom=0.22, left=0.10, right=0.95, hspace=0.35,
                    wspace=0.45)
plt.savefig('inversegaussian.pdf')
